# %%
import pandas as pd
from nltk.tokenize import word_tokenize
import nltk
from collections import Counter

nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/yunusskeete/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df = pd.read_csv(
    "data/Cap3D_automated_Objaverse_full_no3Dword.csv",
    header=None,
    names=["id", "desc"],
)
df
# Out:
#                                       id  \
# 0       ed51a51909ee46c780db3a85e821feb2
# 1       9110b606f6c547b2980fcb3c8c4b6a1c
# 2       80d9caaa1fa04502af666135196456e1
# 3       28d43a218cd8466a8c1f82b29b71e314
# 4       75582285fab442a2ba31733f9c8fae66
# ...                                  ...
# 785145  011a58ba94cb4e89a208e1c30a1d9786
# 785146  b9aa18721f17420a87cee4a89841a858
# 785147  c185d7bfa65c4ca1a8d2518f9c878727
# 785148  fcacc3189f814033989eeab6cdf5ff15
# 785149  4cb693e0715042bb91c961d5ffa12209
#
#                                                                                                                     desc
# 0                                                                                               A green and white rifle.
# 1                 a small building with a roof, accompanied by brown and black shelves, a wooden bench, and a brown box.
# ...

# %%
# Convert descriptions to lowercase
df["desc tokens"] = df["desc"].apply(
    lambda desc: desc.lower().replace("/", " / ").replace("-", " - ")
)

# Tokenize each description
df["desc tokens"] = df["desc tokens"].apply(word_tokenize)
df
# Out:
#                                       id  \
# 0       ed51a51909ee46c780db3a85e821feb2
# 1       9110b606f6c547b2980fcb3c8c4b6a1c
# 2       80d9caaa1fa04502af666135196456e1
# 3       28d43a218cd8466a8c1f82b29b71e314
# 4       75582285fab442a2ba31733f9c8fae66
# ...                                  ...
# 785145  011a58ba94cb4e89a208e1c30a1d9786
# 785146  b9aa18721f17420a87cee4a89841a858
# 785147  c185d7bfa65c4ca1a8d2518f9c878727
# 785148  fcacc3189f814033989eeab6cdf5ff15
# 785149  4cb693e0715042bb91c961d5ffa12209
#
#                                                                                                                     desc  \
# 0                                                                                               A green and white rifle.
# 1                 a small building with a roof, accompanied by brown and black shelves, a wooden bench, and a brown box.
# ...

# %%
# Create the vocabulary
vocab = set()

# Create the word counts
word_counts = {}

for tokens in df["desc tokens"]:
    # Update the vocabulary
    vocab.update([token.replace("'", "") for token in tokens])

    # Count the occurrences of each word
    for word in tokens:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1

# %%
from collections import Counter, OrderedDict

# Convert the dictionary to a Counter object
word_counter = Counter(word_counts)

# Order the Counter object by the number of occurrences
ordered_word_counter = OrderedDict(word_counter.most_common())
ordered_word_counter
# Out:
# OrderedDict([('a', 1494306),
#              (',', 793516),
#              ('.', 670908),
#              ('and', 595421),
#              ('with', 482147),
#              ('white', 272356),
#              ('small', 129610),
#              ('of', 106325),
#              ('on', 100856),
#              ('featuring', 95909),
#              ('black', 92234),
#              ('in', 84256),
#              ('-', 83830),
#              ('blue', 83172),
#              ('wooden', 77424),
#              ('house', 72317),
#              ('green', 71887),
#              ('roof', 64293),
#              ('red', 63676),
#              ('building', 57342),
#              ('yellow', 55579),
#              ('ceiling', 49490),
#              ('resembling', 48489),
#              ('light', 46565),
#              ('the', 42691),
#              ('an', 42162),
#              ('pink', 41344),
#              ('it', 40893),
#              ('box', 40696),
#              ('table', 39903),
# ...

# %%
vocab
# Out:
# {'',
#  'straightening',
#  'chavin',
#  'chibi',
#  'fingered',
#  'salina',
#  'escalators',
#  'ereader',
#  'trk',
#  'mizuno',
#  'aca',
#  'jayi',
#  'gallium',
#  'impression',
#  'amber',
#  'hba',
#  'hallway',
#  'emulus',
#  'furniture',
#  'gantry',
#  'saab',
#  'yti',
#  'tole',
#  'pendant',
#  'headset',
#  'fabshop',
#  'chimes',
#  'libres',
#  'columned',
#  'temple',
#  'particle',
#  'chromebook',
#  'murals',
#  'bike',
#  'grizzly',
#  '6w',
#  'rekla',
#  'ropicos',
#  'dazs',
#  'bullfighter',
#  'kasai',
#  'despina',
#  'fentatole',
#  'suspension',
#  'veggie',
#  'hall',
#  'septic',
#  'rs5',
#  'gynbet',
#  'ironman',
#  'symphonia',
#  'chog',
#  'kodiaq',
#  'alphastarela',
#  'dyny',
#  'weiss',
#  'oils',
#  'juicer',
#  'motherboards',
#  'hourglass',
#  'bx',
#  'assistência',
#  'corral',
#  'drools',
#  'ultrasharp',
#  'chunk',
#  'let',
#  'stilo',
#  'homely',
#  'menu',
#  'fiorentini',
#  'mustaches',
#  'uo',
#  'mapfre',
#  'lebanese',
# ...

# %%
len(vocab)
# Out:
# 26106

# %%
keywords_to_remove
# Out:
# {'art',
#  'design',
#  'island',
#  'light',
#  'marble',
#  'paper',
#  'sculpture',
#  'stone',
#  'torch',
#  'water'}

# %%
keywords_to_add
# Out:
# {'computer',
#  'doorway',
#  'glasses',
#  'ipad',
#  'iphone',
#  'keyboard',
#  'laptop',
#  'macbook',
#  'monitor',
#  'mouse',
#  'phone',
#  'screen',
#  'staircase'}

# %%
keywords_dict = {
    "Furniture": [
        "Swivel",
        "Dresser",
        "Slipper",
        "Futon",
        "Trunk",
        "Wardrobe",
        "Recliner",
        "Barrel",
        "Sofa",
        "Platform",
        "Canopy",
        "Convertible",
        "Poster",
        "Tub",
        "Dressing",
        "Kitchen",
        "Armoire",
        "Shelf",
        "Twin",
        "Waterbed",
        "Stool",
        "Storage",
        "Bar",
        "Washstand",
        "Upholstered",
        "Rocking",
        "Lounge",
        "Rug",
        "Mat",
        "Sideboard",
        "Drawer",
        "Beanbag",
        "Chair",
        "Dining",
        "Chaise",
        "Shoe",
        "Saddle",
        "Rack",
        "Footboard",
        "Nightstand",
        "Desk",
        "Table",
        "Bench",
        "Chest",
        "Couch",
        "Queen",
        "Mattress",
        "Mirror",
        "Stair",
        "Headboard",
        "Cabinet",
        "Armchair",
        "Bunk",
        "Bookshelf",
        "Bed",
        "King",
    ],
    "Materials": [
        "Wallpaper",
        "Steel",
        "Distressed",
        "Ebony",
        "Marble",
        "Rosewood",
        "Bamboo",
        "MDF",
        "Composite",
        "Plywood",
        "Ash",
        "Pine",
        "Mahogany",
        "Spruce",
        "Polyester",
        "Stainless",
        "Linen",
        "Latex",
        "Lacquer",
        "Fir",
        "Fur",
        "Plush",
        "Copper",
        "Melamine",
        "Leather",
        "Poplar",
        "Silk",
        "Vinyl",
        "Acacia",
        "Beech",
        "Cast",
        "Engineered",
        "Cedar",
        "Down",
        "Synthetic",
        "Oak",
        "Brick",
        "Glass",
        "Resin",
        "Birch",
        "Wool",
        "Faux",
        "Wood",
        "Teak",
        "Wood",
        "Aluminum",
        "Hardwood",
        "Iron",
        "Walnut",
        "Laminate",
        "Particleboard",
        "Tile",
        "Suede",
        "Nubuck",
        "Redwood",
        "Acrylic",
        "Velvet",
        "Foam",
        "Maple",
        "Veneer",
        "Brass",
        "Flannel",
        "Microfiber",
        "Satin",
        "Feather",
        "Granite",
        "Cotton",
        "Softwood",
        "Chestnut",
        "Quartz",
        "Concrete",
        "Stone",
    ],
    "Appliances": [
        "Extractor",
        "Grinder",
        "Washer",
        "Cooker",
        "Refrigerator",
        "Warmer",
        "Condenser",
        "Grill",
        "Vegetable",
        "Trash",
        "Can",
        "Juicer",
        "Faucet",
        "Rice",
        "Purifier",
        "Sandwich",
        "Steamer",
        "Coffee",
        "Mixer",
        "Hood",
        "Electric",
        "Range",
        "Induction",
        "Fryer",
        "Blower",
        "Maker",
        "Cooler",
        "Roaster",
        "Dispenser",
        "Microwave",
        "Tap",
        "Chopper",
        "Knife",
        "Rotisserie",
        "Air",
        "Humidifier",
        "Boiler",
        "Blender",
        "Coffeemaker",
        "Tray",
        "Heater",
        "Hob",
        "Shredder",
        "Sink",
        "Processor",
        "Waffle",
        "Dishwasher",
        "Vent",
        "Dehumidifier",
        "Processor",
        "Dryer",
        "Freezer",
        "Fridge",
        "Dehydrator",
        "Chiller",
        "Stove",
        "Popcorn",
        "Kettle",
        "Panini",
        "Scale",
        "Compactor",
        "Toaster",
        "Drier",
        "Mincer",
        "Warming",
        "Fan",
        "Slicer",
        "Oven",
        "Conditioner",
        "Food",
        "Ice",
        "Press",
        "Grill",
        "Appliance",
    ],
    "Decor": [
        "Vase",
        "Planter",
        "Floor",
        "Comfort",
        "Frame",
        "Basket",
        "Body",
        "Cooling",
        "Fountain",
        "Pillow",
        "Clock",
        "Drawing",
        "Blanket",
        "Hanging",
        "Electric",
        "Object",
        "Ornament",
        "Throw",
        "Ceiling",
        "Jar",
        "Bottle",
        "Bedside",
        "Orthopedic",
        "Decorative",
        "Tray",
        "Bowl",
        "Mirror",
        "Holder",
        "Candle",
        "Rug",
        "Mat",
        "Chandelier",
        "Tapestry",
        "Lampshade",
        "Curtain",
        "Plant",
        "Wall",
        "Canvas",
        "Lantern",
        "Picture",
        "Lamp",
        "Pendant",
        "Tassel",
        "Pedestal",
        "Heated",
        "Cushion",
        "Candle",
        "Reading",
        "Painting",
        "Tabletop",
    ],
    "Kitchenware": [
        "Grinder",
        "Pot",
        "Dish",
        "Pin",
        "Jug",
        "Icebox",
        "Teapot",
        "Mat",
        "Pitcher",
        "Utensil",
        "Cork",
        "Bowl",
        "Sink",
        "Spoon",
        "Holder",
        "Rolling",
        "Fridge",
        "Mug",
        "Drying",
        "Board",
        "Roll",
        "Salad",
        "Towel",
        "Corkscrew",
        "Soap",
        "Serving",
        "Faucet",
        "Sieve",
        "Cup",
        "Cooktop",
        "Cutting",
        "Mixing",
        "Hood",
        "Microwave",
        "Tray",
        "Casserole",
        "Dishwasher",
        "Cutlery",
        "Timer",
        "Stove",
        "Pan",
        "Funnel",
        "Platter",
        "Spatula",
        "Organizer",
        "Knife",
        "Whisk",
        "Extractor",
        "Washer",
        "Washing",
        "Machine",
        "Refrigerator",
        "Glass",
        "Masher",
        "Plate",
        "Saucepan",
        "Paper",
        "Opener",
        "Dispenser",
        "Grater",
        "Fork",
        "Dryer",
        "Drain",
        "Ladle",
        "Rack",
        "Ice",
        "Grill",
        "Peeler",
        "Skillet",
        "Measuring",
        "Bottle",
        "Freezer",
        "Shaker",
        "Colander",
        "Strainer",
        "Tongs",
        "Scale",
        "Oven",
        "Coffee",
        "Tea",
    ],
    "Bedroom": [
        "Hamper",
        "Accent",
        "Mat",
        "Stationery",
        "Ceiling",
        "Bedside",
        "Dresser",
        "Holder",
        "Flower",
        "Lampshade",
        "Bedspread",
        "Plant",
        "Cubby",
        "Stand",
        "Fan",
        "Pillowcase",
        "Decoration",
        "Television",
        "Towel",
        "Duvet",
        "Shoes",
        "Trousers",
        "Top",
        "Blouse",
        "Jumper",
        "T-Shirt",
        "Tshirt",
        "Shirt",
        "Skirt",
        "Dress",
        "Scarf",
        "Hat",
        "Slippers",
        "Trunk",
        "Wardrobe",
        "Hanger",
        "Print",
        "Cooler",
        "Sofa",
        "Fireplace",
        "Tray",
        "Bedroom",
        "Remote",
        "Coat",
        "Quilt",
        "Lamp",
        "Cushion",
        "Organizer",
        "Speaker",
        "Drawers",
        "TV",
        "Alarm",
        "Vase",
        "Dressing",
        "Basket",
        "Armoire",
        "Pillow",
        "Shelf",
        "Clock",
        "Stool",
        "Throw",
        "Bin",
        "Storage",
        "Closet",
        "Rug",
        "Shelving",
        "Drawer",
        "Drain",
        "Wall",
        "Chair",
        "Beanbag",
        "Control",
        "Candle",
        "Rack",
        "Frame",
        "Comforter",
        "Footboard",
        "Nightstand",
        "Seat",
        "Desk",
        "Table",
        "Blanket",
        "Carpet",
        "Window",
        "Drapes",
        "Bench",
        "Divider",
        "Chest",
        "Mattress",
        "Heater",
        "Bedsheet",
        "Mirror",
        "Blind",
        "Console",
        "Ottoman",
        "Headboard",
        "Sheet",
        "Curtain",
        "Decor",
        "Blind",
        "Cabinet",
        "Laundry",
        "Picture",
        "Bookshelf",
        "Radiator",
        "Desktop",
        "Bed",
        "Box",
        "Unit",
    ],
    "Bathroom": [
        "Towel",
        "Bath",
        "Soap",
        "Tooth",
        "Dish",
        "Tub",
        "Toilet",
        "Faucet",
        "Seat",
        "Shelf",
        "Sponge",
        "Grout",
        "Mat",
        "Toothbrush",
        "Dispenser",
        "Lotion",
        "Toilette",
        "Bathroom",
        "Heater",
        "Shampoo",
        "Sink",
        "Head",
        "Showerhead",
        "Mirror",
        "Shower",
        "Bathrobe",
        "Curtain",
        "Tile",
        "Cabinet",
        "Linen",
        "Basket",
        "Caddy",
        "StoolDoor",
        "Conditioner",
        "Brush",
        "Rack",
    ],
    "Living Room": [
        "Television",
        "TV",
        "Bookcase",
        "Vase",
        "Sectional",
        "Shade",
        "Floor",
        "Frame",
        "Decorator",
        "SideTable",
        "Apartment",
        "Condo",
        "Entertainment",
        "Shelf",
        "Home",
        "Coffee",
        "Table",
        "Recliner",
        "Clock",
        "Stool",
        "Throw",
        "Sofa",
        "Media",
        "Ceiling",
        "Couch",
        "House",
        "Fireplace",
        "Heater",
        "Furniture",
        "Endtable",
        "Rocking",
        "Lounge",
        "Mirror",
        "Residence",
        "Pouf",
        "Rug",
        "Chandelier",
        "Sideboard",
        "Console",
        "Coatrack",
        "Ottoman",
        "Shelving",
        "Beanbag",
        "Decor",
        "Chair",
        "Plant",
        "Cabinet",
        "Armchair",
        "Curtains",
        "Lamp",
        "Stand",
        "Cushion",
        "Seat",
        "Unit",
    ],
    "Outdoor": [
        "BBQ",
        "Sunshade",
        "Path",
        "Planter",
        "Lounger",
        "Tub",
        "Arbor",
        "Swing",
        "Grill",
        "Deckchair",
        "Slide",
        "Frame",
        "Pit",
        "Tablecloth",
        "Walkway",
        "Pool",
        "Pond",
        "Tree",
        "Car",
        "Bike",
        "Skateboard",
        "Jacuzzi",
        "Deck",
        "Patio",
        "Fountain",
        "Shed",
        "Table",
        "Firewood",
        "Bench",
        "Sofa",
        "Fire",
        "Storage",
        "Set",
        "Pool",
        "Furniture",
        "Heater",
        "Lawn",
        "Garden",
        "Hammock",
        "Barbeque",
        "Umbrella",
        "Swimming",
        "Chair",
        "Lantern",
        "Dining",
        "Porch",
        "Decking",
        "Outdoor",
        "Hot",
        "Picnic",
        "Canopy",
        "Trellis",
        "Box",
        "Barbecue",
        "Gazebo",
        "Tent",
    ],
    "Miscellaneous": [
        "Ladder",
        "Book",
        "Bath",
        "Clothes",
        "Clothing",
        "Line",
        "Planter",
        "Hamper",
        "Pit",
        "Trolley",
        "Toilet",
        "Ladder",
        "Sponge",
        "Mat",
        "Vacuum",
        "Bag",
        "Sink",
        "Hammock",
        "Holder",
        "Fan",
        "Board",
        "Squeegee",
        "Towel",
        "Mop",
        "Soap",
        "Light",
        "Bulb",
        "Awning",
        "Toolset",
        "Trash",
        "Faucet",
        "Deck",
        "Patio",
        "Trunk",
        "Garbage",
        "Hanger",
        "Cooler",
        "Sofa",
        "Bistro",
        "Tray",
        "Furniture",
        "Bucket",
        "Dustpan",
        "Gate",
        "Shower",
        "Coat",
        "Lantern",
        "Stepladder",
        "Lamp",
        "Glider",
        "Cushion",
        "Organizer",
        "Can",
        "Path",
        "Fence",
        "Tub",
        "Basket",
        "Shelf",
        "Rail",
        "Paper",
        "Dispenser",
        "Stool",
        "Bin",
        "Storage",
        "Iron",
        "Bar",
        "Ironing",
        "Rocking",
        "Closet",
        "Rug",
        "Cart",
        "Dryer",
        "Shelving",
        "Drawer",
        "Chair",
        "Chaise",
        "Outdoor",
        "Shoe",
        "Brush",
        "Trellis",
        "Rack",
        "Sectional",
        "Cleaner",
        "Lounger",
        "Duster",
        "Swing",
        "Grill",
        "Bagless",
        "Tissue",
        "Key",
        "Scrubber",
        "Table",
        "Dolly",
        "Broom",
        "Bench",
        "Fire",
        "Liner",
        "Clothes",
        "Heater",
        "Head",
        "Mirror",
        "Utility",
        "Ring",
        "Runner",
        "Plunger",
        "Umbrella",
        "Curtain",
        "Cabinet",
        "Laundry",
        "Hook",
        "Caddy",
        "Scale",
        "Set",
        "Unit",
        "Coat",
        "staircase",
        "keyboard",
        "doorway",
        "glasses",
        "monitor",
        "iphone",
        "computer",
        "laptop",
        "screen",
        "macbook",
        "phone",
        "ipad",
        "mouse",
    ],
}

# %%
keywords = set([item.lower() for sublist in keywords_dict.values() for item in sublist])
len(keywords)
# Out:
# 477

# %%
[kw for kw in keywords_to_add if kw not in keywords]
# Out:
# []

# %%
[kw for kw in keywords_to_remove if kw in keywords]
# Out:
# ['stone', 'light', 'paper', 'marble']

# %%
from typing import List


def check_keywords(tokens: List[str]) -> bool:
    """
    Function to check if at least one keyword exist in description tokens or their plurals.
    """
    return any(((token in keywords) or (f"{token}s" in keywords)) for token in tokens)


# df = df.drop(columns=["include"])

# Apply function to each row
df["include"] = df["desc tokens"].apply(lambda tokens: check_keywords(tokens))
df
# Out:
#                                       id  \
# 0       ed51a51909ee46c780db3a85e821feb2
# 1       9110b606f6c547b2980fcb3c8c4b6a1c
# 2       80d9caaa1fa04502af666135196456e1
# 3       28d43a218cd8466a8c1f82b29b71e314
# 4       75582285fab442a2ba31733f9c8fae66
# ...                                  ...
# 785145  011a58ba94cb4e89a208e1c30a1d9786
# 785146  b9aa18721f17420a87cee4a89841a858
# 785147  c185d7bfa65c4ca1a8d2518f9c878727
# 785148  fcacc3189f814033989eeab6cdf5ff15
# 785149  4cb693e0715042bb91c961d5ffa12209
#
#                                                                                                                     desc  \
# 0                                                                                               A green and white rifle.
# 1                 a small building with a roof, accompanied by brown and black shelves, a wooden bench, and a brown box.
# ...

# %%
filtered_df = df[df["include"] == True]
len(filtered_df)
# Out:
# 495653

# %%
keywords_to_remove = set()
keywords_to_add = set()

# %%
idx = 93
[token for token in df.iloc[idx]["desc tokens"] if token in keywords]
# Out:
# ['umbrella']

# %%
word = "water"
if word in keywords:
    print(True)
    keywords_to_remove.add(word)

    print(keywords_to_remove)
# Out:
# True
# {'art', 'stone', 'water', 'light', 'paper', 'torch', 'marble', 'design', 'sculpture', 'island'}

# %%
"glasses" in keywords
# Out:
# False

# %%
keywords_to_add.add("glasses")
keywords_to_add
# Out:
# {'computer',
#  'doorway',
#  'glasses',
#  'ipad',
#  'iphone',
#  'keyboard',
#  'laptop',
#  'macbook',
#  'monitor',
#  'mouse',
#  'phone',
#  'screen',
#  'staircase'}

# %%
# # Set the display width to max
# pd.set_option('display.max_colwidth', None)
# Set the display width to max
pd.set_option("display.max_colwidth", 150)
# # Reset display.max_colwidth to its default value (50)
# pd.reset_option('display.max_colwidth')
filtered_df["desc"].sample(50)
# Out:
# 312544                                                                                                     A mannequin wearing a pink and purple tie-dye dress.
# 315071                                                                           a small white table with a glass top, a staircase, and a square ceiling light.
# 266168                                                                                                                  yellow and white striped ball and ring.
# 428740                  Gold-plated objects collection: pendant with swan head, winged bag, sculpture, vase, Spartan helmet, cape with large hood, and penguin.
# 332801                                                                                                       a white staircase with an arrow and ceiling light.
# 249805                              a circular trampoline with a solar panel, featuring a white and blue ring, blue water, and a concrete dome with blue light.
# ...

# %%
excluded_df = df[df["include"] == False]
len(excluded_df)
# Out:
# 289497

# %%
remove_idxs = [
    519050,
    733175,
    179989,
    580882,
    154977,
    149578,
    197129,
    703126,
    215440,
    303744,
    157730,
    335460,
    226691,
    772500,
    264240,
    510504,
    660575,
    157641,
    696004,
    416435,
    448744,
    359576,
    718225,
    591343,
    129921,
    604997,
    354810,
]

# %%
excluded_df["desc"].sample(50)
# Out:
# 452033                                                                                                                                a rotten turnip.
# 699409                                                                a man in a blue hoodie and black pants, also depicted as a ninja with blue hair.
# 46566                                                                                                        a blue United Nations shipping container.
# 483728                                                                                                                                 a ship or boat.
# 232852                                                                         a row of red and blue poles, resembling a playground or bridge railing.
# 711984                                                                                                            a black AT-ST robot with its arms up
# ...

# %%
["glasses", "mannequin", "radio"]
